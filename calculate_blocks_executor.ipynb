# %%
# ---- user config ----
YOUR_NAME = 'sara'
AWS_PROFILE = 'cities'

# If you want to limit the run (debug):
# LIMIT = 20
LIMIT = None

# Cities to ignore for now
IGNORE_CITIES = [
    'Ngo__Nigeria',
    'Bugama__Nigeria',
    'Mubi__Nigeria',
    'San_Pedro_de_Macoris__Dominican_Republic',
]

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# ---- shared S3 paths (mirrors gather_data_executor + pre_processing.py) ----
MAIN_PATH = 's3://wri-cities-sandbox/identifyingLandSubdivisions/data'
INPUT_PATH = f'{MAIN_PATH}/input'
CITY_INFO_PATH = f'{INPUT_PATH}/city_info'
EXTENTS_PATH = f'{CITY_INFO_PATH}/extents'
BUILDINGS_PATH = f'{INPUT_PATH}/buildings'
ROADS_PATH = f'{INPUT_PATH}/roads'
INTERSECTIONS_PATH = f'{INPUT_PATH}/intersections'
NATURAL_FEATURES_PATH = f'{INPUT_PATH}/natural_features_and_railroads'
BLOCKS_PATH = f'{INPUT_PATH}/blocks'
OUTPUT_PATH = f'{MAIN_PATH}/output'

# %%
# ---- check S3 connection using AWS_PROFILE ----
import boto3, os

session = boto3.Session(profile_name=AWS_PROFILE)
s3 = session.client('s3')

# Export profile so s3fs/cloudpathlib inherit it
os.environ['AWS_PROFILE'] = AWS_PROFILE

s3.list_buckets()
# Out:
# {'ResponseMetadata': {'RequestId': '9DFNAN6J8TMMEEZ7',
#   'HostId': 'isSydAaNxMW7pFUoDEpp4IK9mnPd4wCbE8Tkd5o56u5xXUpxpp4m1lWwuVWjKnonrLHk/kQ8l8sUR1tds42o+rJFAWu9ovPb',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'isSydAaNxMW7pFUoDEpp4IK9mnPd4wCbE8Tkd5o56u5xXUpxpp4m1lWwuVWjKnonrLHk/kQ8l8sUR1tds42o+rJFAWu9ovPb',
#    'x-amz-request-id': '9DFNAN6J8TMMEEZ7',
#    'date': 'Sat, 28 Mar 2026 19:42:30 GMT',
#    'content-type': 'application/xml',
#    'transfer-encoding': 'chunked',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'Buckets': [{'Name': 'aft-sandbox-540362055257',
#    'CreationDate': datetime.datetime(2022, 9, 13, 15, 12, 20, tzinfo=tzutc()),
#    'BucketArn': 'arn:aws:s3:::aft-sandbox-540362055257'},
#   {'Name': 'amplify-citiesindicatorsapi-dev-10508-deployment',
#    'CreationDate': datetime.datetime(2023, 8, 30, 5, 5, 13, tzinfo=tzutc()),
#    'BucketArn': 'arn:aws:s3:::amplify-citiesindicatorsapi-dev-10508-deployment'},
#   {'Name': 'cities-heat',
#    'CreationDate': datetime.datetime(2023, 6, 1, 13, 22, 1, tzinfo=tzutc()),
#    'BucketArn': 'arn:aws:s3:::cities-heat'},
#   {'Name': 'cities-test-sandbox',
#    'CreationDate': datetime.datetime(2025, 4, 18, 19, 10, 49, tzinfo=tzutc()),
#    'BucketArn': 'arn:aws:s3:::cities-test-sandbox'},
#   {'Name': 'do-not-delete-ssm-diagnosis-540362055257-us-east-1-hac7u',
#    'CreationDate': datetime.datetime(2025, 7, 7, 9, 3, 18, tzinfo=tzutc()),
#    'BucketArn': 'arn:aws:s3:::do-not-delete-ssm-diagnosis-540362055257-us-east-1-hac7u'},
#   {'Name': 'era5-brazil',
#    'CreationDate': datetime.datetime(2025, 2, 15, 19, 51, 14, tzinfo=tzutc()),
#    'BucketArn': 'arn:aws:s3:::era5-brazil'},
#   {'Name': 'wri-cities-athena-us-east-1',
#    'CreationDate': datetime.datetime(2025, 7, 17, 13, 37, 24, tzinfo=tzutc()),
#    'BucketArn': 'arn:aws:s3:::wri-cities-athena-us-east-1'},
#   {'Name': 'wri-cities-athena-us-west-2',
#    'CreationDate': datetime.datetime(2024, 1, 12, 18, 45, 11, tzinfo=tzutc()),
#    'BucketArn': 'arn:aws:s3:::wri-cities-athena-us-west-2'},
#   {'Name': 'wri-cities-aws',
#    'CreationDate': datetime.datetime(2025, 7, 15, 18, 56, 37, tzinfo=tzutc()),
#    'BucketArn': 'arn:aws:s3:::wri-cities-aws'},
#   {'Name': 'wri-cities-climate-hazards',
#    'CreationDate': datetime.datetime(2024, 1, 3, 16, 57, 31, tzinfo=tzutc()),
#    'BucketArn': 'arn:aws:s3:::wri-cities-climate-hazards'},
#   {'Name': 'wri-cities-data-api',
#    'CreationDate': datetime.datetime(2024, 7, 16, 8, 53, 31, tzinfo=tzutc()),
#    'BucketArn': 'arn:aws:s3:::wri-cities-data-api'},
#   {'Name': 'wri-cities-heat',
#    'CreationDate': datetime.datetime(2024, 3, 25, 15, 46, 55, tzinfo=tzutc()),
#    'BucketArn': 'arn:aws:s3:::wri-cities-heat'},
#   {'Name': 'wri-cities-indicators',
#    'CreationDate': datetime.datetime(2024, 5, 13, 15, 50, 58, tzinfo=tzutc()),
#    'BucketArn': 'arn:aws:s3:::wri-cities-indicators'},
#   {'Name': 'wri-cities-sandbox',
#    'CreationDate': datetime.datetime(2024, 7, 27, 0, 51, 38, tzinfo=tzutc()),
#    'BucketArn': 'arn:aws:s3:::wri-cities-sandbox'},
#   {'Name': 'wri-cities-tcm',
#    'CreationDate': datetime.datetime(2025, 8, 29, 19, 35, 51, tzinfo=tzutc()),
#    'BucketArn': 'arn:aws:s3:::wri-cities-tcm'}],
#  'Owner': {'ID': 'df12253943982d72f60594f06c2cacf9a1ee3a9e738c1649c9fb96e5127f1a5c'}}

# %%
# ---- start Coiled cluster (adjust n_workers / instance type as needed) ----
import coiled

cluster = coiled.Cluster(
    workspace='wri-cities-data',
    name=f'ils-blocks-{YOUR_NAME}',
    region='us-west-2',
    arm=True,
    worker_vm_types='r8g.xlarge',
    spot_policy='spot',
    n_workers=10,
    package_sync_ignore=['pyspark', 'pypandoc'],
    worker_options={'nthreads': 1},
)
client = cluster.get_client()
print(f'Started Dask client. Dashboard: {client.dashboard_link}')
# Out:
# [2026-03-28 14:42:32,902][INFO    ][coiled] Using existing cluster: 'ils-blocks-sara (id: 1532277)'
# [2026-03-28 14:42:32,903][INFO    ][coiled] Attaching to existing cluster (name: ils-blocks-sara, https://cloud.coiled.io/clusters/1532277 )
# /opt/anaconda3/envs/subdivisions2/lib/python3.12/site-packages/google/auth/_default.py:76: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# Started Dask client. Dashboard: https://cluster-tbkve.dask.host/n3bhXPfBK9dCy-B6/status
# /opt/anaconda3/envs/subdivisions2/lib/python3.12/site-packages/distributed/client.py:1590: VersionMismatchWarning: Mismatched versions found
#
# +---------+--------+-----------+---------+
# | Package | Client | Scheduler | Workers |
# +---------+--------+-----------+---------+
# | lz4     | 4.4.4  | 4.4.5     | 4.4.5   |
# +---------+--------+-----------+---------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))

# %%
import s3fs
fs = s3fs.S3FileSystem()

# ---- Step 1: Get ALL cities that have roads (our master list) ----
road_city_dirs = fs.ls(ROADS_PATH)
all_cities = sorted([p.split('/')[-1] for p in road_city_dirs if p.split('/')[-1] not in ['.DS_Store', '']])
print(f"Total cities with roads: {len(all_cities)}")

# ---- Step 2: Find cities that ALREADY have blocks ----
already_done = []
for city in all_cities:
    blocks_file = f"{BLOCKS_PATH}/{city}/{city}_blocks_{YOUR_NAME}.geoparquet"
    try:
        if fs.exists(blocks_file):
            already_done.append(city)
    except Exception:
        pass

print(f"Cities with blocks already done: {len(already_done)}")

# ---- Step 3: Filter to missing cities that have required baseline inputs ----
missing_cities = [c for c in all_cities if c not in set(already_done) and c not in set(IGNORE_CITIES)]
print(f"Cities missing blocks (excl. ignored): {len(missing_cities)}")

# Check required inputs for each missing city
UE_PATH = f"{INPUT_PATH}/urban_extent"
UE200_PATH = f"{INPUT_PATH}/urban_extent_200m_buffer"

ready_cities = []
not_ready = []

for city in missing_cities:
    roads_ok = fs.exists(f"{ROADS_PATH}/{city}/{city}_OSM_roads.geoparquet")
    nf_ok = fs.exists(f"{NATURAL_FEATURES_PATH}/{city}/{city}_OSM_natural_features_and_railroads.geoparquet")
    ue_ok = fs.exists(f"{UE_PATH}/{city}/{city}_urban_extent.geoparquet")
    ue200_ok = fs.exists(f"{UE200_PATH}/{city}/{city}_urban_extent_200m_buffer.geoparquet")
    
    if roads_ok and nf_ok and ue_ok and ue200_ok:
        ready_cities.append(city)
    else:
        not_ready.append({'city': city, 'roads': roads_ok, 'nf': nf_ok, 'ue': ue_ok, 'ue200': ue200_ok})

print(f"\nReady to run blocks: {len(ready_cities)}")
print(f"Missing some inputs: {len(not_ready)}")

if not_ready:
    import pandas as pd
    nr_df = pd.DataFrame(not_ready)
    print("\nMissing inputs breakdown:")
    for col in ['roads', 'nf', 'ue', 'ue200']:
        n_missing = (~nr_df[col]).sum()
        if n_missing > 0:
            print(f"  missing {col}: {n_missing}")
    print(f"\nFirst 10 not-ready cities:")
    print(nr_df.head(10).to_string(index=False))

cities = ready_cities
print(f"\n>>> Will run {len(cities)} cities")

if LIMIT:
    cities = cities[:LIMIT]
    print(f"LIMIT applied -> {len(cities)}")
# Out:
# Total cities with roads: 1234
# Cities with blocks already done: 1152
# Cities missing blocks (excl. ignored): 82
#
# Ready to run blocks: 82
# Missing some inputs: 0
#
# >>> Will run 82 cities

# %%
# ---- logging + runner (inspired by gather_data_executor) ----
import os, time, socket, traceback
from datetime import datetime, timezone
from cloudpathlib import S3Path

from pre_processing import produce_blocks

RUN_ID = datetime.utcnow().strftime('%Y%m%dT%H%M%SZ')
LOGS_S3_DIR = f"{OUTPUT_PATH}/logs/blocks_calculation/{RUN_ID}"
SUMMARY_S3_PATH = f"{LOGS_S3_DIR}/summary.csv"
LOCAL_LOG_DIR = f"/tmp/blocks_calculation_logs/{RUN_ID}"


def utc_now():
    return datetime.now(timezone.utc).strftime('%Y-%m-%dT%H:%M:%SZ')


def append_log(path, msg):
    os.makedirs(os.path.dirname(path), exist_ok=True)
    with open(path, 'a', encoding='utf-8') as f:
        f.write(msg)


def safe_s3_upload(local_path, s3_uri):
    s3p = S3Path(s3_uri)
    s3p.parent.mkdir(parents=True, exist_ok=True)
    s3p.upload_from(local_path)
    return s3_uri


def blocks_already_exist(city):
    # pre_processing saves: {BLOCKS_PATH}/{city}/{city}_blocks_{YOUR_NAME}.geoparquet
    s3_uri = f"{BLOCKS_PATH}/{city}/{city}_blocks_{YOUR_NAME}.geoparquet"
    try:
        return fs.exists(s3_uri)
    except Exception:
        return False


def required_inputs_exist(city):
    paths = {
        'roads': f"{ROADS_PATH}/{city}/{city}_OSM_roads.geoparquet",
        'natural_features': f"{NATURAL_FEATURES_PATH}/{city}/{city}_OSM_natural_features_and_railroads.geoparquet",
    }
    exists = {}
    ok = True
    for k, p in paths.items():
        try:
            ex = fs.exists(p)
        except Exception:
            ex = False
        exists[k] = ex
        ok = ok and ex
    return ok, exists


def run_city_blocks(city):
    city_clean = city.strip()
    host = socket.gethostname()
    log_path = os.path.join(LOCAL_LOG_DIR, f"{city_clean}.log")

    append_log(log_path, f"[{utc_now()}] START city={city_clean} host={host} run_id={RUN_ID}\n")

    if city_clean in IGNORE_CITIES:
        append_log(log_path, f"[{utc_now()}] SKIP city is in IGNORE_CITIES\n")
        s3_log = safe_s3_upload(log_path, f"{LOGS_S3_DIR}/{city_clean}.log")
        return {'city': city_clean, 'status': 'skipped_ignore', 'log_s3': s3_log}

    if blocks_already_exist(city_clean):
        append_log(log_path, f"[{utc_now()}] SKIP blocks already exist for YOUR_NAME={YOUR_NAME}\n")
        s3_log = safe_s3_upload(log_path, f"{LOGS_S3_DIR}/{city_clean}.log")
        return {'city': city_clean, 'status': 'skipped_exists', 'log_s3': s3_log}

    ok_inputs, exists = required_inputs_exist(city_clean)
    if not ok_inputs:
        append_log(log_path, f"[{utc_now()}] FAIL missing inputs: {exists}\n")
        s3_log = safe_s3_upload(log_path, f"{LOGS_S3_DIR}/{city_clean}.log")
        out = {'city': city_clean, 'status': 'missing_inputs', 'log_s3': s3_log}
        out.update({f"has_{k}": v for k, v in exists.items()})
        return out

    t0 = time.time()
    dt = None
    try:
        blocks = produce_blocks(city_clean, YOUR_NAME).compute()
        n = 0 if blocks is None else len(blocks)
        dt = time.time() - t0
        append_log(log_path, f"[{utc_now()}] OK blocks={n} elapsed_sec={dt:.2f}\n")
        status = 'ok'
        extra = {'n_blocks': n}
    except Exception as e:
        dt = time.time() - t0
        append_log(log_path, f"[{utc_now()}] ERROR elapsed_sec={dt:.2f} err={repr(e)}\n")
        append_log(log_path, traceback.format_exc() + "\n")
        status = 'error'
        extra = {}

    s3_log = safe_s3_upload(log_path, f"{LOGS_S3_DIR}/{city_clean}.log")
    out = {'city': city_clean, 'status': status, 'elapsed_sec': dt, 'log_s3': s3_log}
    out.update(extra)
    return out
# Out:
# /var/folders/nn/3mdkp6sx1n3d955f3wqgdbb00000gn/T/ipykernel_4647/3138404732.py:8: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   RUN_ID = datetime.utcnow().strftime('%Y%m%dT%H%M%SZ')

# %%
# ---- execute across cities with dask.bag ----
import dask.bag as db
import pandas as pd

bag = db.from_sequence(cities, partition_size=1)

records = bag.map(run_city_blocks).compute()

summary = pd.DataFrame(records)
print(summary['status'].value_counts(dropna=False))

local_summary = f"/tmp/summary_blocks_calculation_{RUN_ID}.csv"
summary.to_csv(local_summary, index=False, sep=';')

S3Path(LOGS_S3_DIR).mkdir(parents=True, exist_ok=True)
S3Path(SUMMARY_S3_PATH).upload_from(local_summary)

print('✅ Summary written to:', SUMMARY_S3_PATH)
# Out:
# status
# ok    82
# Name: count, dtype: int64
# ✅ Summary written to: s3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/logs/blocks_calculation/20260328T194802Z/summary.csv

# %%
import s3fs
fs = s3fs.S3FileSystem()

BLOCKS_PATH = "wri-cities-sandbox/identifyingLandSubdivisions/data/input/blocks"

block_cities = []
for city_dir in fs.ls(BLOCKS_PATH):
    city = city_dir.split('/')[-1]
    if city in ['.DS_Store', '']:
        continue
    files = [f for f in fs.ls(city_dir) if f.endswith('_blocks_sara.geoparquet')]
    if files:
        block_cities.append(city)

print(f"Cities with blocks: {len(block_cities)}")
# Out:
# Cities with blocks: 1234

# %%
import geopandas as gpd

# Bujumbura
buj = gpd.read_parquet("s3://wri-cities-sandbox/identifyingLandSubdivisions/data/input/blocks/Bujumbura__Burundi/Bujumbura__Burundi_blocks_sara.geoparquet")
buj.to_file("../data/input/blocks/Bujumbura_blocks.shp")

# Kigali
kig = gpd.read_parquet("s3://wri-cities-sandbox/identifyingLandSubdivisions/data/input/blocks/Kigali__Rwanda/Kigali__Rwanda_blocks_sara.geoparquet")
kig.to_file("../data/input/blocks/Kigali_blocks.shp")
# Out:
# /var/folders/nn/3mdkp6sx1n3d955f3wqgdbb00000gn/T/ipykernel_17480/4169478447.py:5: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   buj.to_file("../data/input/blocks/Bujumbura_blocks.shp")
# /opt/anaconda3/envs/subdivisions2/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'optimal_point' to 'optimal_po'
#   ogr_write(
# /opt/anaconda3/envs/subdivisions2/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'is_fill_block' to 'is_fill_bl'
#   ogr_write(
# /opt/anaconda3/envs/subdivisions2/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'fill_method' to 'fill_metho'
#   ogr_write(
# /var/folders/nn/3mdkp6sx1n3d955f3wqgdbb00000gn/T/ipykernel_17480/4169478447.py:9: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   kig.to_file("../data/input/blocks/Kigali_blocks.shp")
# /opt/anaconda3/envs/subdivisions2/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'optimal_point' to 'optimal_po'
#   ogr_write(
# /opt/anaconda3/envs/subdivisions2/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'is_fill_block' to 'is_fill_bl'
#   ogr_write(
# /opt/anaconda3/envs/subdivisions2/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'fill_method' to 'fill_metho'
#   ogr_write(

# %%
NF_PATH = "wri-cities-sandbox/identifyingLandSubdivisions/data/input/natural_features_and_railroads"

empty_nf = []
for city_dir in fs.ls(NF_PATH):
    city = city_dir.split('/')[-1]
    if city in ['.DS_Store', '']:
        continue
    files = [f for f in fs.ls(city_dir) if f.endswith('_OSM_natural_features_and_railroads.geoparquet')]
    if files and fs.info(files[0])['size'] == 6508:
        empty_nf.append(city)

print(f"Cities with empty natural features: {len(empty_nf)}")
for c in empty_nf:
    print(f"  {c}")
# Out:
# Cities with empty natural features: 116
#   Abiriba__Nigeria
#   Agbor__Nigeria
#   Akugba__Nigeria
#   Alaba_Kulito__Ethiopia
#   Amakofia__Nigeria
#   Ambovombe__Madagascar
#   Ankpa__Nigeria
#   Aramoko_Ekiti__Nigeria
#   Arsi_Negelle__Ethiopia
#   Asassa__Ethiopia
#   Ayangba__Nigeria
#   Azare__Nigeria
#   Berekum__Ghana
#   Bertoua__Cameroon
#   Bohicon__Benin
#   Bule_Hora__Ethiopia
#   Chiro__Ethiopia
#   Dadaab__Kenya
#   Dambarta__Nigeria
#   Dambidollo__Ethiopia
#   Damboa__Nigeria
#   Daura__Nigeria
#   Demba__Democratic_Republic_of_the_Congo
#   Djougou__Benin
#   Doka_Ashafa__Nigeria
#   Durame__Ethiopia
#   Dutse__Nigeria
#   Effon_Alaiye__Nigeria
#   Egbe__Nigeria
#   Ejigbo__Nigeria
#   Ekpoma__Nigeria
#   El_Wak__Kenya
#   Epe__Nigeria
#   Erigavo__Somalia
#   Fik__Ethiopia
#   Filtu__Ethiopia
#   Fresnillo__Mexico
#   Funtua__Nigeria
#   Gabela__Angola
#   Galkayo__Somalia
#   Geita__Tanzania
#   Gumel__Nigeria
#   Hossana__Ethiopia
#   Ido_Ekiti__Nigeria
#   Igbe__Nigeria
#   Igboho__Nigeria
#   Ijebu_Ode__Nigeria
#   Ijero_Ekiti__Nigeria
#   Ikole__Nigeria
#   Ilaro__Nigeria
#   Ile_Oluji__Nigeria
#   Ilesa__Nigeria
#   Iquique__Chile
#   Irri__Nigeria
#   Isanlu_Mopo__Nigeria
#   Ishiagu__Nigeria
#   Iwere__Nigeria
#   Jimma__Ethiopia
#   Kabba__Nigeria
#   Kabondo_Dianda__Democratic_Republic_of_the_Congo
#   Kabongo__Democratic_Republic_of_the_Congo
#   Kahemba__Democratic_Republic_of_the_Congo
#   Kanyama__Democratic_Republic_of_the_Congo
#   Kasongo__Democratic_Republic_of_the_Congo
#   Katoro__Tanzania
#   Katsiro__Nigeria
#   Kefole__Ethiopia
#   Kilwa__Democratic_Republic_of_the_Congo
#   Kinzao__Democratic_Republic_of_the_Congo
#   Kishi__Nigeria
#   Kismayo__Somalia
#   Kitenge__Democratic_Republic_of_the_Congo
#   Koko__Nigeria
#   Kombolcha__Ethiopia
#   Koumra__Chad
#   Langtang__Nigeria
#   Lawmu_Umunze__Nigeria
#   Louga__Senegal
#   Luau__Angola
#   Lubao__Democratic_Republic_of_the_Congo
#   Luiza__Democratic_Republic_of_the_Congo
#   Malumfashi__Nigeria
#   Mandeville__Jamaica
#   Misau__Nigeria
#   Mogadishu__Somalia
#   Mojo__Ethiopia
#   Mokwa__Nigeria
#   Morocho__Ethiopia
#   Mwene_Ditu__Democratic_Republic_of_the_Congo
#   Ngandajika__Democratic_Republic_of_the_Congo
#   Nguru__Nigeria
#   Ningi__Nigeria
#   Nkongsamba__Cameroon
#   Nouadhibou__Mauritania
#   Nyunzu__Democratic_Republic_of_the_Congo
#   Obudu__Nigeria
#   Oka_Akoko__Nigeria
#   Omu_Aran__Nigeria
#   Omuo_Obadore__Nigeria
#   Otukpo__Nigeria
#   Otun__Nigeria
#   Owo__Nigeria
#   Pobe__Benin
#   Rumbek__South_Sudan
#   Sahagun__Colombia
#   Shashamane__Ethiopia
#   Shema__Nigeria
#   Tarzoho__Nigeria
#   Touba__Senegal
#   Tuga_Nama__Nigeria
#   Umu_Lawlaw__Nigeria
#   Uromi__Nigeria
#   Wajir__Kenya
#   Waliso__Ethiopia
#   Xawo_Tako__Somalia
#   kazaure__Nigeria

# %%
empty_nf
# Out:
# ['Abiriba__Nigeria',
#  'Agbor__Nigeria',
#  'Akugba__Nigeria',
#  'Alaba_Kulito__Ethiopia',
#  'Amakofia__Nigeria',
#  'Ambovombe__Madagascar',
#  'Ankpa__Nigeria',
#  'Aramoko_Ekiti__Nigeria',
#  'Arsi_Negelle__Ethiopia',
#  'Asassa__Ethiopia',
#  'Ayangba__Nigeria',
#  'Azare__Nigeria',
#  'Berekum__Ghana',
#  'Bertoua__Cameroon',
#  'Bohicon__Benin',
#  'Bule_Hora__Ethiopia',
#  'Chiro__Ethiopia',
#  'Dadaab__Kenya',
#  'Dambarta__Nigeria',
#  'Dambidollo__Ethiopia',
#  'Damboa__Nigeria',
#  'Daura__Nigeria',
#  'Demba__Democratic_Republic_of_the_Congo',
#  'Djougou__Benin',
#  'Doka_Ashafa__Nigeria',
#  'Durame__Ethiopia',
#  'Dutse__Nigeria',
#  'Effon_Alaiye__Nigeria',
#  'Egbe__Nigeria',
#  'Ejigbo__Nigeria',
#  'Ekpoma__Nigeria',
#  'El_Wak__Kenya',
#  'Epe__Nigeria',
#  'Erigavo__Somalia',
#  'Fik__Ethiopia',
#  'Filtu__Ethiopia',
#  'Fresnillo__Mexico',
#  'Funtua__Nigeria',
#  'Gabela__Angola',
#  'Galkayo__Somalia',
#  'Geita__Tanzania',
#  'Gumel__Nigeria',
#  'Hossana__Ethiopia',
#  'Ido_Ekiti__Nigeria',
#  'Igbe__Nigeria',
#  'Igboho__Nigeria',
#  'Ijebu_Ode__Nigeria',
#  'Ijero_Ekiti__Nigeria',
#  'Ikole__Nigeria',
#  'Ilaro__Nigeria',
#  'Ile_Oluji__Nigeria',
#  'Ilesa__Nigeria',
#  'Iquique__Chile',
#  'Irri__Nigeria',
#  'Isanlu_Mopo__Nigeria',
#  'Ishiagu__Nigeria',
#  'Iwere__Nigeria',
#  'Jimma__Ethiopia',
#  'Kabba__Nigeria',
#  'Kabondo_Dianda__Democratic_Republic_of_the_Congo',
#  'Kabongo__Democratic_Republic_of_the_Congo',
#  'Kahemba__Democratic_Republic_of_the_Congo',
#  'Kanyama__Democratic_Republic_of_the_Congo',
#  'Kasongo__Democratic_Republic_of_the_Congo',
#  'Katoro__Tanzania',
#  'Katsiro__Nigeria',
#  'Kefole__Ethiopia',
#  'Kilwa__Democratic_Republic_of_the_Congo',
#  'Kinzao__Democratic_Republic_of_the_Congo',
#  'Kishi__Nigeria',
#  'Kismayo__Somalia',
#  'Kitenge__Democratic_Republic_of_the_Congo',
#  'Koko__Nigeria',
#  'Kombolcha__Ethiopia',
#  'Koumra__Chad',
#  'Langtang__Nigeria',
#  'Lawmu_Umunze__Nigeria',
#  'Louga__Senegal',
#  'Luau__Angola',
#  'Lubao__Democratic_Republic_of_the_Congo',
#  'Luiza__Democratic_Republic_of_the_Congo',
#  'Malumfashi__Nigeria',
#  'Mandeville__Jamaica',
#  'Misau__Nigeria',
#  'Mogadishu__Somalia',
#  'Mojo__Ethiopia',
#  'Mokwa__Nigeria',
#  'Morocho__Ethiopia',
#  'Mwene_Ditu__Democratic_Republic_of_the_Congo',
#  'Ngandajika__Democratic_Republic_of_the_Congo',
#  'Nguru__Nigeria',
#  'Ningi__Nigeria',
#  'Nkongsamba__Cameroon',
#  'Nouadhibou__Mauritania',
#  'Nyunzu__Democratic_Republic_of_the_Congo',
#  'Obudu__Nigeria',
#  'Oka_Akoko__Nigeria',
#  'Omu_Aran__Nigeria',
#  'Omuo_Obadore__Nigeria',
#  'Otukpo__Nigeria',
#  'Otun__Nigeria',
#  'Owo__Nigeria',
#  'Pobe__Benin',
#  'Rumbek__South_Sudan',
#  'Sahagun__Colombia',
#  'Shashamane__Ethiopia',
#  'Shema__Nigeria',
#  'Tarzoho__Nigeria',
#  'Touba__Senegal',
#  'Tuga_Nama__Nigeria',
#  'Umu_Lawlaw__Nigeria',
#  'Uromi__Nigeria',
#  'Wajir__Kenya',
#  'Waliso__Ethiopia',
#  'Xawo_Tako__Somalia',
#  'kazaure__Nigeria']

# %%
# ---- quick peek at failures ----
# Show a few errors/missing inputs for debugging

import pandas as pd

errs = summary[summary['status'].isin(['error', 'missing_inputs'])].copy()
print('n problematic:', len(errs))
errs.head(25)

# %% [markdown]
# ### Notes
# - This notebook builds the city list from existing **ROADS** folders on S3, then skips the 4 ignore cities.
# - It also skips cities where a blocks file already exists for this `YOUR_NAME`.
# - Logs and a summary CSV are uploaded to: `s3://.../output/logs/calc_blocks/<RUN_ID>/`.
