# %% [markdown]
# # Variables

# %%
YOUR_NAME = 'sara'

AWS_PROFILE = 'cities'

'''
# List of cities to process
cities = ["Belo Horizonte", "Campinas"]#, "Bogota", "Nairobi", "Bamako", 
        #"Lagos", "Accra", "Abidjan", "Mogadishu", "Cape Town", 
        #"Maputo", "Luanda"]

test_cities = ["Belo Horizonte"]
#cities = test_cities

cities = [city.replace(' ', '_') for city in cities]

search_buffer_files = fs.ls(SEARCH_BUFFER_PATH)

cities 

number_of_cities = len(cities)

print(f'City count: {number_of_cities}')
'''
grid_size = 200

# %% [markdown]
# # Setup

# %%
# %load_ext autoreload

# %%
MAIN_PATH = "s3://wri-cities-sandbox/identifyingLandSubdivisions/data"
INPUT_PATH = f'{MAIN_PATH}/input'
CITY_INFO_PATH = f'{INPUT_PATH}/city_info'
EXTENTS_PATH = f'{CITY_INFO_PATH}/extents'
BUILDINGS_PATH = f'{INPUT_PATH}/buildings'
ROADS_PATH = f'{INPUT_PATH}/roads'
INTERSECTIONS_PATH = f'{INPUT_PATH}/intersections'
GRIDS_PATH = f'{INPUT_PATH}/city_info/grids'
SEARCH_BUFFER_PATH = f'{INPUT_PATH}/city_info/search_buffers'
OUTPUT_PATH = f'{MAIN_PATH}/output'
OUTPUT_PATH_CSV = f'{OUTPUT_PATH}/csv'
OUTPUT_PATH_RASTER = f'{OUTPUT_PATH}/raster'
OUTPUT_PATH_PNG = f'{OUTPUT_PATH}/png'
OUTPUT_PATH_RAW = f'{OUTPUT_PATH}/raw_results'

# %%
# Check s3 connection using AWS_PROFILE=CitiesUserPermissionSet profile 
import boto3

session = boto3.Session(profile_name=AWS_PROFILE)
s3 = session.client('s3')

# export CitiesUserPermissionSet profile to use in the next cells
import os
os.environ['AWS_PROFILE'] = AWS_PROFILE


s3.list_buckets()
# Out:
# {'ResponseMetadata': {'RequestId': 'C86CG7E3KVM6WRZ6',
#   'HostId': 'dyxFhpXoS5es6DHd0coe1ufBS8w99evhjMUBa5q7NuVu2VMYf6H0o+TTVXzCEXR3jJGZNkNVhJIgNfdDlRO+qBLpx4piFGqVvABH1YsT9J8=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'dyxFhpXoS5es6DHd0coe1ufBS8w99evhjMUBa5q7NuVu2VMYf6H0o+TTVXzCEXR3jJGZNkNVhJIgNfdDlRO+qBLpx4piFGqVvABH1YsT9J8=',
#    'x-amz-request-id': 'C86CG7E3KVM6WRZ6',
#    'date': 'Sun, 16 Mar 2025 21:14:41 GMT',
#    'content-type': 'application/xml',
#    'transfer-encoding': 'chunked',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'Buckets': [{'Name': 'aft-sandbox-540362055257',
#    'CreationDate': datetime.datetime(2022, 9, 13, 15, 12, 20, tzinfo=tzutc())},
#   {'Name': 'amplify-citiesindicatorsapi-dev-10508-deployment',
#    'CreationDate': datetime.datetime(2023, 8, 30, 5, 5, 13, tzinfo=tzutc())},
#   {'Name': 'cities-dev-sandbox',
#    'CreationDate': datetime.datetime(2025, 2, 7, 23, 18, 12, tzinfo=tzutc())},
#   {'Name': 'cities-heat',
#    'CreationDate': datetime.datetime(2023, 6, 1, 13, 22, 1, tzinfo=tzutc())},
#   {'Name': 'era5-brazil',
#    'CreationDate': datetime.datetime(2025, 2, 15, 19, 51, 14, tzinfo=tzutc())},
#   {'Name': 'wri-cities-athena-us-west-2',
#    'CreationDate': datetime.datetime(2024, 1, 12, 18, 45, 11, tzinfo=tzutc())},
#   {'Name': 'wri-cities-climate-hazards',
#    'CreationDate': datetime.datetime(2024, 1, 3, 16, 57, 31, tzinfo=tzutc())},
#   {'Name': 'wri-cities-data-api',
#    'CreationDate': datetime.datetime(2024, 7, 16, 8, 53, 31, tzinfo=tzutc())},
#   {'Name': 'wri-cities-heat',
#    'CreationDate': datetime.datetime(2024, 3, 25, 15, 46, 55, tzinfo=tzutc())},
#   {'Name': 'wri-cities-indicators',
#    'CreationDate': datetime.datetime(2024, 5, 13, 15, 50, 58, tzinfo=tzutc())},
#   {'Name': 'wri-cities-sandbox',
#    'CreationDate': datetime.datetime(2024, 7, 27, 0, 51, 38, tzinfo=tzutc())}],
#  'Owner': {'DisplayName': 'aws-cities',
#   'ID': 'df12253943982d72f60594f06c2cacf9a1ee3a9e738c1649c9fb96e5127f1a5c'}}

# %%
import coiled

cluster = coiled.Cluster(
    workspace="wri-cities-data",
    name=f'ils-{YOUR_NAME}',
    region="us-west-2",
    arm=True,
    worker_vm_types="r8g.xlarge",
    spot_policy="spot",
    n_workers=8,
    package_sync_ignore=["pyspark", "pypandoc"]
)
client = cluster.get_client()

print(f"Started a new Dask client on Coiled. Dashboard is available at {client.dashboard_link}")
# Out:
# [2025-03-16 16:14:43,862][INFO    ][coiled] Fetching latest package priorities...
# [2025-03-16 16:14:43,863][INFO    ][coiled.package_sync] Resolving your local subdivisions2 Python environment...
# [2025-03-16 16:14:44,902][INFO    ][coiled.package_sync] Scanning 442 conda packages...
# [2025-03-16 16:14:44,910][INFO    ][coiled.package_sync] Scanning 257 python packages...
# [2025-03-16 16:14:46,390][INFO    ][coiled] Running pip check...
# [2025-03-16 16:14:48,457][INFO    ][coiled] Validating environment...
# [2025-03-16 16:14:50,687][INFO    ][coiled] Creating wheel for ~/Documents/Identifying Land Subdivisions/identifyingLandSubdivisions...
# [2025-03-16 16:14:50,974][WARNING ][coiled.package_sync] Package - libopenvino-intel-cpu-plugin, libopenvino-intel-cpu-plugin~=2025.0.0 has no install candidate for Python 3.12 linux-aarch64 on conda-forge
# [2025-03-16 16:14:50,975][INFO    ][coiled] Uploading coiled_local_identifyingLandSubdivisions...
# [2025-03-16 16:14:52,907][INFO    ][coiled] Requesting package sync build...
# [2025-03-16 16:14:53,961][INFO    ][coiled] Creating Cluster (name: ils-sara, https://cloud.coiled.io/clusters/798156?account=wri-cities-data ). This usually takes 1-2 minutes...
# Started a new Dask client on Coiled. Dashboard is available at https://cluster-rwpaj.dask.host/g4kkOFG404UNYL_O/status
# Exception in callback None()
# handle: <Handle cancelled>
# Traceback (most recent call last):
#   File "/Users/sarangof/miniconda3/envs/subdivisions2/lib/python3.12/site-packages/tornado/iostream.py", line 1367, in _do_ssl_handshake
#     self.socket.do_handshake()
#   File "/Users/sarangof/miniconda3/envs/subdivisions2/lib/python3.12/ssl.py", line 1319, in do_handshake
#     self._sslobj.do_handshake()
# ssl.SSLEOFError: [SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1010)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/sarangof/miniconda3/envs/subdivisions2/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/sarangof/miniconda3/envs/subdivisions2/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 202, in _handle_events
#     handler_func(fileobj, events)
#   File "/Users/sarangof/miniconda3/envs/subdivisions2/lib/python3.12/site-packages/tornado/iostream.py", line 691, in _handle_events
#     self._handle_read()
#   File "/Users/sarangof/miniconda3/envs/subdivisions2/lib/python3.12/site-packages/tornado/iostream.py", line 1427, in _handle_read
#     self._do_ssl_handshake()
#   File "/Users/sarangof/miniconda3/envs/subdivisions2/lib/python3.12/site-packages/tornado/iostream.py", line 1376, in _do_ssl_handshake
#     return self.close(exc_info=err)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sarangof/miniconda3/envs/subdivisions2/lib/python3.12/site-packages/tornado/iostream.py", line 606, in close
#     self._signal_closed()
#   File "/Users/sarangof/miniconda3/envs/subdivisions2/lib/python3.12/site-packages/tornado/iostream.py", line 636, in _signal_closed
#     self._ssl_connect_future.exception()
# asyncio.exceptions.CancelledError
# Exception in callback None()
# handle: <Handle cancelled>
# Traceback (most recent call last):
#   File "/Users/sarangof/miniconda3/envs/subdivisions2/lib/python3.12/site-packages/tornado/iostream.py", line 1367, in _do_ssl_handshake
#     self.socket.do_handshake()
#   File "/Users/sarangof/miniconda3/envs/subdivisions2/lib/python3.12/ssl.py", line 1319, in do_handshake
#     self._sslobj.do_handshake()
# ssl.SSLEOFError: [SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1010)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/sarangof/miniconda3/envs/subdivisions2/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/sarangof/miniconda3/envs/subdivisions2/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 202, in _handle_events
#     handler_func(fileobj, events)
#   File "/Users/sarangof/miniconda3/envs/subdivisions2/lib/python3.12/site-packages/tornado/iostream.py", line 691, in _handle_events
#     self._handle_read()
#   File "/Users/sarangof/miniconda3/envs/subdivisions2/lib/python3.12/site-packages/tornado/iostream.py", line 1427, in _handle_read
#     self._do_ssl_handshake()
#   File "/Users/sarangof/miniconda3/envs/subdivisions2/lib/python3.12/site-packages/tornado/iostream.py", line 1376, in _do_ssl_handshake
#     return self.close(exc_info=err)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sarangof/miniconda3/envs/subdivisions2/lib/python3.12/site-packages/tornado/iostream.py", line 606, in close
#     self._signal_closed()
#   File "/Users/sarangof/miniconda3/envs/subdivisions2/lib/python3.12/site-packages/tornado/iostream.py", line 636, in _signal_closed
#     self._ssl_connect_future.exception()
# asyncio.exceptions.CancelledError
# Exception in callback None()
# handle: <Handle cancelled>
# Traceback (most recent call last):
#   File "/Users/sarangof/miniconda3/envs/subdivisions2/lib/python3.12/site-packages/tornado/iostream.py", line 1367, in _do_ssl_handshake
#     self.socket.do_handshake()
#   File "/Users/sarangof/miniconda3/envs/subdivisions2/lib/python3.12/ssl.py", line 1319, in do_handshake
#     self._sslobj.do_handshake()
# ssl.SSLEOFError: [SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1010)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/sarangof/miniconda3/envs/subdivisions2/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/sarangof/miniconda3/envs/subdivisions2/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 202, in _handle_events
#     handler_func(fileobj, events)
#   File "/Users/sarangof/miniconda3/envs/subdivisions2/lib/python3.12/site-packages/tornado/iostream.py", line 691, in _handle_events
#     self._handle_read()
#   File "/Users/sarangof/miniconda3/envs/subdivisions2/lib/python3.12/site-packages/tornado/iostream.py", line 1427, in _handle_read
#     self._do_ssl_handshake()
#   File "/Users/sarangof/miniconda3/envs/subdivisions2/lib/python3.12/site-packages/tornado/iostream.py", line 1376, in _do_ssl_handshake
#     return self.close(exc_info=err)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sarangof/miniconda3/envs/subdivisions2/lib/python3.12/site-packages/tornado/iostream.py", line 606, in close
#     self._signal_closed()
#   File "/Users/sarangof/miniconda3/envs/subdivisions2/lib/python3.12/site-packages/tornado/iostream.py", line 636, in _signal_closed
#     self._ssl_connect_future.exception()
# asyncio.exceptions.CancelledError
# 2025-03-16 17:18:53,663 - distributed.client - ERROR - Failed to reconnect to scheduler after 30.00 seconds, closing client

# %% [markdown]
# # RUN

# %%
import s3fs
import fsspec
import traceback

import os


fs = s3fs.S3FileSystem(anon=False)
search_buffer_files = fs.ls(SEARCH_BUFFER_PATH)

cities = [x.split('/')[-1] for x in search_buffer_files]
len(cities)
# Out:
# 406

# %%
from post_processing import *


#process_category(BUILDINGS_PATH, "buildings_combined")

#folder_path ='s3://wri-cities-sandbox/identifyingLandSubdivisions/data/input/buildings/Abeokuta'
#city_name = Path(folder_path).name  # Extract city name
#files = fs.ls(folder_path)
#geo_file = next(f for f in files if f.endswith(".geoparquet"))  # Find the file
#gdf = gpd.read_parquet('s3://wri-cities-sandbox/identifyingLandSubdivisions/data/input/buildings/Abeokuta/Overture_building_Abeokuta.geoparquet')

#dgpd.read_parquet('wri-cities-sandbox/identifyingLandSubdivisions/data/input/intersections/Abeokuta/Abeokuta_OSM_intersections.geoparquet', npartitions=2).compute()
#gdf["city_name"] = city_name  # Add city identifier

#read_city_geoparquet(f'{BUILDINGS_PATH}/Accra/')
#city_folders = list_city_folders(BUILDINGS_PATH)
#folder_path='s3://wri-cities-sandbox/identifyingLandSubdivisions/data/input/buildings/Abeokuta'
#city_name = Path(folder_path).name
#files = fs.ls(folder_path)
#geo_file = next(f for f in files if f.endswith(".geoparquet"))
#geo_file
#read_city_geoparquet('wri-cities-sandbox/identifyingLandSubdivisions/data/input/buildings/Abeokuta')
    


#process_category_dask(BUILDINGS_PATH,f'{BUILDINGS_PATH}/cities_combined')
process_category_dask(INTERSECTIONS_PATH,f'{INTERSECTIONS_PATH}/cities_combined')
                      
#process_raster_dask(OUTPUT_PATH_RASTER,f'{OUTPUT_PATH_RASTER}/cities_combined')

#process_raster(OUTPUT_PATH_RASTER)
# Out:
# 🔍 Checking geometry column in s3://wri-cities-sandbox/identifyingLandSubdivisions/data/input/intersections/cities_combined: osmid             object
# y                float64
# x                float64
# street_count       int64
# geometry        geometry
# city_name         object
# highway           object
# junction          object
# railway           object
# ref               object
# dtype: object
#  Successfully saved s3://wri-cities-sandbox/identifyingLandSubdivisions/data/input/intersections/cities_combined to S3!
# 🔍 S3 Files in s3://wri-cities-sandbox/identifyingLandSubdivisions/data/input/intersections/cities_combined: ['wri-cities-sandbox/identifyingLandSubdivisions/data/input/intersections/cities_combined/data.parquet']

# %%
import dask.dataframe as dd


dd.read_parquet(f'{INTERSECTIONS_PATH}/cities_combined/data.parquet').compute().to_parquet(f'{INTERSECTIONS_PATH}/cities_combined.parquet')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[39], line 4
#       1 import dask.dataframe as dd
# ----> 4 dd.read_parquet(f'{INTERSECTIONS_PATH}/cities_combined/data.parquet').compute().to_parquet(f'{INTERSECTIONS_PATH}/cities_combined.parquet')
#
# File ~/miniconda3/envs/subdivisions2/lib/python3.12/site-packages/dask/dataframe/dask_expr/_collection.py:489, in FrameBase.compute(self, fuse, concatenate, **kwargs)
#     487     out = out.repartition(npartitions=1)
#     488 out = out.optimize(fuse=fuse)
# --> 489 return DaskMethodsMixin.compute(out, **kwargs)
#
# File ~/miniconda3/envs/subdivisions2/lib/python3.12/site-packages/dask/base.py:374, in DaskMethodsMixin.compute(self, **kwargs)
#     350 def compute(self, **kwargs):
#     351     """Compute this dask collection
#     352
#     353     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     372     dask.compute
#     373     """
# --> 374     (result,) = compute(self, traverse=False, **kwargs)
#     375     return result
#
# File ~/miniconda3/envs/subdivisions2/lib/python3.12/site-packages/dask/base.py:662, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     659     postcomputes.append(x.__dask_postcompute__())
#     661 with shorten_traceback():
# --> 662     results = schedule(dsk, keys, **kwargs)
#     664 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~/miniconda3/envs/subdivisions2/lib/python3.12/threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File ~/miniconda3/envs/subdivisions2/lib/python3.12/threading.py:359, in Condition.wait(self, timeout)
#     357 else:
#     358     if timeout > 0:
# --> 359         gotit = waiter.acquire(True, timeout)
#     360     else:
#     361         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
gdf.compute()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 gdf.compute()
#
# File ~/miniconda3/envs/subdivisions2/lib/python3.12/site-packages/dask/dataframe/dask_expr/_collection.py:489, in FrameBase.compute(self, fuse, concatenate, **kwargs)
#     487     out = out.repartition(npartitions=1)
#     488 out = out.optimize(fuse=fuse)
# --> 489 return DaskMethodsMixin.compute(out, **kwargs)
#
# File ~/miniconda3/envs/subdivisions2/lib/python3.12/site-packages/dask/base.py:374, in DaskMethodsMixin.compute(self, **kwargs)
#     350 def compute(self, **kwargs):
#     351     """Compute this dask collection
#     352
#     353     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     372     dask.compute
#     373     """
# --> 374     (result,) = compute(self, traverse=False, **kwargs)
#     375     return result
#
# File ~/miniconda3/envs/subdivisions2/lib/python3.12/site-packages/dask/base.py:662, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     659     postcomputes.append(x.__dask_postcompute__())
#     661 with shorten_traceback():
# --> 662     results = schedule(dsk, keys, **kwargs)
#     664 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~/miniconda3/envs/subdivisions2/lib/python3.12/threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File ~/miniconda3/envs/subdivisions2/lib/python3.12/threading.py:359, in Condition.wait(self, timeout)
#     357 else:
#     358     if timeout > 0:
# --> 359         gotit = waiter.acquire(True, timeout)
#     360     else:
#     361         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
import dask_geopandas as dgpd
from dask import delayed, compute, visualize
from dask.diagnostics import ProgressBar
# %autoreload
from citywide_calculation import get_utm_crs
from metrics_calculation import calculate_minimum_distance_to_roads_option_B
from shapely.geometry import MultiLineString, LineString

@delayed
def get_epsg(city_name):
    search_buffer = f'{SEARCH_BUFFER_PATH}/{city_name}/{city_name}_search_buffer.geoparquet'
    extent = dgpd.read_parquet(search_buffer)
    geometry = extent.geometry[0].compute()
    epsg = get_utm_crs(geometry)
    print(f'{city_name} EPSG: {epsg}')
    return epsg

@delayed
def load_dataset(path, epsg=None):
    """Load a single parquet dataset"""
    dataset = dgpd.read_parquet(path, npartitions=2)
    if epsg:
        dataset = dataset.set_crs("EPSG:4326", allow_override=True) 
        dataset = dataset.to_crs(epsg=epsg)
    return dataset

@delayed
def row_count(dgdf):
    """Count the rows in a dataframe"""
    row_count = dgdf.map_partitions(len).compute().sum()

    return row_count

def test_math(input):
    return input + input

# %autoreload
from metrics_groupby import metrics

@delayed
def metrics(city_name,YOUR_NAME,grid_size):
    grid_cell_count = 0
    paths = {
        'grid': f'{GRIDS_PATH}/{city_name}/{city_name}_{str(grid_size)}m_grid.geoparquet',
        'buildings': f'{BUILDINGS_PATH}/{city_name}/Overture_building_{city_name}.geoparquet',
        'roads': f'{ROADS_PATH}/{city_name}/{city_name}_OSM_roads.geoparquet',
        'intersections': f'{INTERSECTIONS_PATH}/{city_name}/{city_name}_OSM_intersections.geoparquet'
    }
    # Get EPSG
    epsg = get_epsg(city_name)
    # Load grid
    grid = load_dataset(paths['grid'], epsg=epsg).compute()
    if 'geom' in grid.columns:
        grid = grid.drop(columns=['geom'])
    grid['cell_area'] = grid.geometry.area

    cells = grid.index.size
    grid_cell_count += cells.compute()

    # Load buildings and perform relevant calculations on it
    buildings = load_dataset(paths['buildings'], epsg=epsg).compute()
    buildings['area'] = buildings.geometry.area
    joined_buildings = dgpd.sjoin(buildings, grid, predicate='within')  
    counts_buildings = joined_buildings.groupby('index_right').size()
    grid['n_buildings'] = grid.index.map(counts_buildings).fillna(0).astype(int)
    built_area_buildings = joined_buildings.groupby('index_right')['area'].sum()
    grid['built_area'] = grid.index.map(built_area_buildings).fillna(0).astype(float)

    #total_buildings = row_count(buildings).compute()
    #print(total_buildings)
    # Load roads
    #roads = load_dataset(paths['roads'], epsg=epsg).compute()
    #road_union = roads.unary_union.compute()
    # Load intersections
    intersections = load_dataset(paths['intersections'], epsg=epsg).compute()
    print(type(intersections))
    intersections_3plus = intersections[intersections.street_count >= 3]
    print(type(intersections_3plus))
    intersections_4way = intersections[intersections.street_count == 4]
    print(type(intersections_4way))

    '''
    buildings['distance_to_road'] = buildings['geometry'].map_partitions(
        lambda partition: partition.apply(lambda geom: calculate_minimum_distance_to_roads_option_B(geom, road_union)),
        meta=('distance_to_road', 'float64')
    )
    
    buildings_within_10m_of_buildings = buildings[buildings.distance_to_road <= 20]
    joined_buildings_within_10m_of_buildings = dgpd.sjoin(buildings_within_10m_of_buildings, grid, predicate='within')
    counts_buildings_within_10m_of_buildings = joined_buildings_within_10m_of_buildings.groupby('index_right').size()
    grid['n_buildings_within_10m_of_roads'] = grid.index.map(counts_buildings_within_10m_of_buildings).fillna(0).astype(int)
    joined_buildings_distance_to_road = dgpd.sjoin(buildings[['geometry', 'distance_to_road']], grid, predicate='within')
    # NOT SURE OF THIS YET
    averaged_buildings_distance_to_road = joined_buildings_distance_to_road.groupby('index_right')['distance_to_road'].mean()
    grid['average_distance_to_closest_roads'] = grid.index.map(averaged_buildings_distance_to_road).fillna(0).astype(int)
    '''
    joined_intersections_3plus = dgpd.sjoin(intersections_3plus, grid, predicate='within')
    counts_intersections_3plus = joined_intersections_3plus.groupby('index_right').size()
    grid['intersections_3plus'] = grid.index.map(counts_intersections_3plus).fillna(0).astype(int)

    joined_intersections_4way = dgpd.sjoin(intersections_4way, grid, predicate='within')
    counts_intersections_4way = joined_intersections_4way.groupby('index_right').size()
    grid['intersections_4way'] = grid.index.map(counts_intersections_4way).fillna(0).astype(int)
    
    '''
    grid['m1'] = grid['n_buildings_within_10m_of_roads'] / grid['n_buildings']
    grid['m2'] = grid['average_distance_to_closest_roads']
    '''

    grid['m4'] = grid['intersections_4way'] / grid['intersections_3plus']


    grid['m11'] = 1.0*grid['n_buildings'] / grid['cell_area'] # Building density
    grid['m12'] = grid['built_area'] / grid['cell_area'] # Built area share
    grid['m13'] = grid['built_area'] / grid['n_buildings'] # Average building area

    path = f'{OUTPUT_PATH_RASTER}/{city_name}/{city_name}_{str(grid_size)}m_grid_{YOUR_NAME}.geoparquet'
    grid.to_parquet(path)
    return grid_cell_count, path

# %%
metrics('Accra', YOUR_NAME, grid_size=grid_size).compute()
# Out:
# Accra EPSG: 32630
# Accra EPSG: 32630
# /Users/sarangof/miniconda3/envs/subdivisions2/lib/python3.12/site-packages/dask/dataframe/dask_expr/_collection.py:4729: UserWarning:
# You did not provide metadata, so Dask is running your function on a small dataset to guess output types. It is possible that Dask will guess incorrectly.
# To provide an explicit output types or to silence this message, please provide the `meta=` keyword, as described in the map or apply function that you are using.
#   warnings.warn(meta_warning(meta))
# /Users/sarangof/miniconda3/envs/subdivisions2/lib/python3.12/site-packages/dask/dataframe/dask_expr/_collection.py:4729: UserWarning:
# You did not provide metadata, so Dask is running your function on a small dataset to guess output types. It is possible that Dask will guess incorrectly.
# To provide an explicit output types or to silence this message, please provide the `meta=` keyword, as described in the map or apply function that you are using.
#   warnings.warn(meta_warning(meta))
# Accra EPSG: 32630
# <class 'dask_geopandas.expr.GeoDataFrame'>
# <class 'dask_geopandas.expr.GeoDataFrame'>
# <class 'dask_geopandas.expr.GeoDataFrame'>
# /Users/sarangof/miniconda3/envs/subdivisions2/lib/python3.12/site-packages/dask/dataframe/dask_expr/_collection.py:4729: UserWarning:
# You did not provide metadata, so Dask is running your function on a small dataset to guess output types. It is possible that Dask will guess incorrectly.
# To provide an explicit output types or to silence this message, please provide the `meta=` keyword, as described in the map or apply function that you are using.
#   warnings.warn(meta_warning(meta))
# /Users/sarangof/miniconda3/envs/subdivisions2/lib/python3.12/site-packages/dask/dataframe/dask_expr/_collection.py:4729: UserWarning:
# You did not provide metadata, so Dask is running your function on a small dataset to guess output types. It is possible that Dask will guess incorrectly.
# To provide an explicit output types or to silence this message, please provide the `meta=` keyword, as described in the map or apply function that you are using.
#   warnings.warn(meta_warning(meta))
# (2900,
#  's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Accra/Accra_200m_grid_sara.geoparquet')

# %%
print(cities)

# Create delayed tasks for counting
grid_calculations = []

for city_name in cities:
    grid_calc = metrics(city_name, YOUR_NAME, grid_size=grid_size)
    grid_calculations.append(grid_calc)

#visualize(*grid_calulations)
calculated_grids = compute(*grid_calculations)
calculated_grids
# Out:
# ['Abeokuta', 'Abidjan', 'Abuja', 'Accra', 'Addis_Ababa', 'Aden', 'Agra', 'Agri', 'Ahmadabad', 'Aleppo', 'Alexandria', 'Algiers', 'Aligarh', 'Alor_Star', 'Amman', 'Amravati', 'Ankara', 'Annaba', 'Anqing', 'Antalya', 'Antananarivo', 'Anyang', 'Arak', 'Arusha', 'Asuncion', 'Bac_Lieu', 'Bacolod', 'Baghdad', 'Baku', 'Bamako', 'Bamenda', 'Bandar_Lampung', 'Bandung', 'Bangkok', 'Bangui', 'Banjarbaru', 'Bankura', 'Barquisimeto', 'Barranquilla', 'Barreiras', 'Barretos', 'Bauchi', 'Beijing', 'Beira', 'Beirut', 'Belem', 'Belo_Horizonte', 'Benxi', 'Bhimavaram', 'Bhopal', 'Bicheng', 'Bilaspur', 'Bilbeis', 'Bogor', 'Bogota', 'Bou_Saada', 'Bouake', 'Buenos_Aires', 'Bukavu', 'Bukhara', 'Buraydah', 'Burewala', 'Bursa', 'Busan', 'Cabimas', 'Cabo_Frio', 'Cairo', 'Cali', 'Campinas', 'Can_Tho', 'Cape_Town', 'Caracas', 'Cartagena', 'Casablanca', 'Cebu_City', 'Changzhi', 'Changzhou', 'Chengde', 'Chengdu', 'Chennai', 'Chenzhou', 'Chittoor', 'Chongqing', 'Cirebon', 'Cochabamba', 'Coimbatore', 'Conakry', 'Constantine', 'Cordoba', 'Culiacan', 'Curico', 'Curitiba', 'Dakar', 'Dalat', 'Daloa', 'Damascus', 'Dar_es_Salaam', 'David', 'Denpasar', 'Dezhou', 'Dhaka', 'Dinajpur', 'Diyarbakir', 'Djibouti', 'Doha', 'Douala', 'Dubai', 'Durban', 'Enugu', 'Erbil', 'Eskisehir', 'Faisalabad', 'Feira_De_Santana', 'Fez', 'Florianopolis', 'Fortaleza', 'Freetown', 'Fuzhou', 'Gandhidham', 'Ganja', 'Gaya', 'Gaza', 'Gemena', 'Goiania', 'Gombe', 'Gorgan', 'Guadalajara', 'Guatemala_City', 'Guelmim', 'Guixi', 'Gujranwala', 'Gwangju', 'Haikou', 'Hama', 'Hangzhou', 'Harbin', 'Havana', 'Hengyang', 'Heze', 'Hindaun', 'Hindupur', 'Holguin', 'Hong_Kong', 'Huambo', 'Huancayo', 'Hue', 'Hyderabad', 'Ibadan', 'Ibb', 'Idlib', 'Ilheus', 'Ipoh', 'Isiro', 'Istanbul', 'Izmir', 'Izmit', 'Jaipur', 'Jakarta', 'Jalna', 'Jambi', 'Jeddah', 'Jequie', 'Jerusalem', 'Jiamusi', 'Jiancheng', 'Jimeta', 'Jinan', 'Jingzhou', 'Jinjiang', 'Jiujiang', 'Joao_Pessoa', 'Johannesburg', 'Jolo', 'Jos', 'Juazeiro_Do_Norte', 'Juba', 'Kabul', 'Kabwe', 'Kaduna', 'Kaiping', 'Kairouan', 'Kampala', 'Kano', 'Kanpur', 'Karachi', 'Karbala', 'Kathmandu', 'Kayseri', 'Keren', 'Khargone', 'Khartoum', 'Khurja', 'Kigali', 'Kinshasa', 'Kirkuk', 'Kolkata', 'Konya', 'Kozhikode', 'Kuala_Lumpur', 'Kuching', 'Kumasi', 'Kunming', 'Kuwait_City', 'La_Paz', 'Laghouat', 'Lagos', 'Lahore', 'Lashio', 'Leiyang', 'Leizhou', 'Leon', 'Leshan', 'Libreville', 'Lima', 'Lingbao', 'Linyi', 'Luanda', 'Lubumbashi', 'Lucknow', 'Ludhiana', 'Lusaka', 'Luxor', 'Macapa', 'Malatya', 'Malegaon', 'Manaus', 'Mandalay', 'Manisa', 'Maputo', 'Maracaibo', 'Maringa', 'Marj', 'Maroua', 'Marrakesh', 'Mary', 'Mashhad', 'Mawlamyine', 'Mbuji-Mayi', 'Medan', 'Medellin', 'Medina', 'Meknes', 'Mendoza', 'Merida', 'Misrata', 'Mit_Ghamr', 'Mogadishu', 'Monteria', 'Monterrey', 'Montevideo', 'Moradabad', 'Mosul', 'Mumbai', 'My_Tho', 'Myeik', 'Nagpur', 'Nairobi', 'Najaf', 'Nakuru', 'Nalgonda', 'Namangan', 'Nanchang', 'Nanjing', 'Nashik', 'Nasiriyah', 'Ndola', 'Nouakchott', 'Oshogbo', 'Osorno', 'Ouagadougou', 'Oujda', 'Oyo', 'Padang', 'Palembang', 'Palmas', 'Palopo', 'Panipat', 'Parbhani', 'Pathein', 'Patna', 'Pekalongan', 'Pemalang', 'Pematang_Siantar', 'Phnom_Penh', 'Pingxiang', 'Pingyi', 'Pokhara', 'Polokwane', 'Pontianak']
# ((1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Abeokuta/Abeokuta_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Abidjan/Abidjan_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Abuja/Abuja_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Accra/Accra_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Addis_Ababa/Addis_Ababa_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Aden/Aden_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Agra/Agra_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Agri/Agri_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Ahmadabad/Ahmadabad_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Aleppo/Aleppo_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Alexandria/Alexandria_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Algiers/Algiers_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Aligarh/Aligarh_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Alor_Star/Alor_Star_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Amman/Amman_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Amravati/Amravati_200m_grid_sara.geoparquet'),
#  (2,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Ankara/Ankara_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Annaba/Annaba_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Anqing/Anqing_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Antalya/Antalya_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Antananarivo/Antananarivo_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Anyang/Anyang_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Arak/Arak_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Arusha/Arusha_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Asuncion/Asuncion_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Bac_Lieu/Bac_Lieu_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Bacolod/Bacolod_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Baghdad/Baghdad_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Baku/Baku_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Bamako/Bamako_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Bamenda/Bamenda_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Bandar_Lampung/Bandar_Lampung_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Bandung/Bandung_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Bangkok/Bangkok_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Bangui/Bangui_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Banjarbaru/Banjarbaru_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Bankura/Bankura_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Barquisimeto/Barquisimeto_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Barranquilla/Barranquilla_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Barreiras/Barreiras_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Barretos/Barretos_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Bauchi/Bauchi_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Beijing/Beijing_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Beira/Beira_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Beirut/Beirut_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Belem/Belem_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Belo_Horizonte/Belo_Horizonte_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Benxi/Benxi_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Bhimavaram/Bhimavaram_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Bhopal/Bhopal_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Bicheng/Bicheng_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Bilaspur/Bilaspur_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Bilbeis/Bilbeis_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Bogor/Bogor_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Bogota/Bogota_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Bou_Saada/Bou_Saada_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Bouake/Bouake_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Buenos_Aires/Buenos_Aires_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Bukavu/Bukavu_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Bukhara/Bukhara_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Buraydah/Buraydah_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Burewala/Burewala_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Bursa/Bursa_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Busan/Busan_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Cabimas/Cabimas_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Cabo_Frio/Cabo_Frio_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Cairo/Cairo_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Cali/Cali_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Campinas/Campinas_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Can_Tho/Can_Tho_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Cape_Town/Cape_Town_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Caracas/Caracas_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Cartagena/Cartagena_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Casablanca/Casablanca_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Cebu_City/Cebu_City_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Changzhi/Changzhi_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Changzhou/Changzhou_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Chengde/Chengde_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Chengdu/Chengdu_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Chennai/Chennai_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Chenzhou/Chenzhou_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Chittoor/Chittoor_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Chongqing/Chongqing_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Cirebon/Cirebon_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Cochabamba/Cochabamba_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Coimbatore/Coimbatore_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Conakry/Conakry_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Constantine/Constantine_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Cordoba/Cordoba_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Culiacan/Culiacan_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Curico/Curico_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Curitiba/Curitiba_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Dakar/Dakar_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Dalat/Dalat_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Daloa/Daloa_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Damascus/Damascus_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Dar_es_Salaam/Dar_es_Salaam_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/David/David_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Denpasar/Denpasar_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Dezhou/Dezhou_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Dhaka/Dhaka_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Dinajpur/Dinajpur_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Diyarbakir/Diyarbakir_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Djibouti/Djibouti_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Doha/Doha_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Douala/Douala_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Dubai/Dubai_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Durban/Durban_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Enugu/Enugu_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Erbil/Erbil_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Eskisehir/Eskisehir_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Faisalabad/Faisalabad_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Feira_De_Santana/Feira_De_Santana_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Fez/Fez_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Florianopolis/Florianopolis_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Fortaleza/Fortaleza_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Freetown/Freetown_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Fuzhou/Fuzhou_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Gandhidham/Gandhidham_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Ganja/Ganja_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Gaya/Gaya_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Gaza/Gaza_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Gemena/Gemena_200m_grid_sara.geoparquet'),
#  (2,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Goiania/Goiania_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Gombe/Gombe_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Gorgan/Gorgan_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Guadalajara/Guadalajara_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Guatemala_City/Guatemala_City_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Guelmim/Guelmim_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Guixi/Guixi_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Gujranwala/Gujranwala_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Gwangju/Gwangju_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Haikou/Haikou_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Hama/Hama_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Hangzhou/Hangzhou_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Harbin/Harbin_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Havana/Havana_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Hengyang/Hengyang_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Heze/Heze_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Hindaun/Hindaun_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Hindupur/Hindupur_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Holguin/Holguin_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Hong_Kong/Hong_Kong_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Huambo/Huambo_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Huancayo/Huancayo_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Hue/Hue_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Hyderabad/Hyderabad_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Ibadan/Ibadan_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Ibb/Ibb_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Idlib/Idlib_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Ilheus/Ilheus_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Ipoh/Ipoh_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Isiro/Isiro_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Istanbul/Istanbul_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Izmir/Izmir_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Izmit/Izmit_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Jaipur/Jaipur_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Jakarta/Jakarta_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Jalna/Jalna_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Jambi/Jambi_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Jeddah/Jeddah_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Jequie/Jequie_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Jerusalem/Jerusalem_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Jiamusi/Jiamusi_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Jiancheng/Jiancheng_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Jimeta/Jimeta_200m_grid_sara.geoparquet'),
#  (2,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Jinan/Jinan_200m_grid_sara.geoparquet'),
#  (2,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Jingzhou/Jingzhou_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Jinjiang/Jinjiang_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Jiujiang/Jiujiang_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Joao_Pessoa/Joao_Pessoa_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Johannesburg/Johannesburg_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Jolo/Jolo_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Jos/Jos_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Juazeiro_Do_Norte/Juazeiro_Do_Norte_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Juba/Juba_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Kabul/Kabul_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Kabwe/Kabwe_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Kaduna/Kaduna_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Kaiping/Kaiping_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Kairouan/Kairouan_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Kampala/Kampala_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Kano/Kano_200m_grid_sara.geoparquet'),
#  (2,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Kanpur/Kanpur_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Karachi/Karachi_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Karbala/Karbala_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Kathmandu/Kathmandu_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Kayseri/Kayseri_200m_grid_sara.geoparquet'),
#  (2,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Keren/Keren_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Khargone/Khargone_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Khartoum/Khartoum_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Khurja/Khurja_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Kigali/Kigali_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Kinshasa/Kinshasa_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Kirkuk/Kirkuk_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Kolkata/Kolkata_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Konya/Konya_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Kozhikode/Kozhikode_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Kuala_Lumpur/Kuala_Lumpur_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Kuching/Kuching_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Kumasi/Kumasi_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Kunming/Kunming_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Kuwait_City/Kuwait_City_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/La_Paz/La_Paz_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Laghouat/Laghouat_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Lagos/Lagos_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Lahore/Lahore_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Lashio/Lashio_200m_grid_sara.geoparquet'),
#  (2,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Leiyang/Leiyang_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Leizhou/Leizhou_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Leon/Leon_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Leshan/Leshan_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Libreville/Libreville_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Lima/Lima_200m_grid_sara.geoparquet'),
#  (2,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Lingbao/Lingbao_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Linyi/Linyi_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Luanda/Luanda_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Lubumbashi/Lubumbashi_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Lucknow/Lucknow_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Ludhiana/Ludhiana_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Lusaka/Lusaka_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Luxor/Luxor_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Macapa/Macapa_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Malatya/Malatya_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Malegaon/Malegaon_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Manaus/Manaus_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Mandalay/Mandalay_200m_grid_sara.geoparquet'),
#  (2,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Manisa/Manisa_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Maputo/Maputo_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Maracaibo/Maracaibo_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Maringa/Maringa_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Marj/Marj_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Maroua/Maroua_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Marrakesh/Marrakesh_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Mary/Mary_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Mashhad/Mashhad_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Mawlamyine/Mawlamyine_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Mbuji-Mayi/Mbuji-Mayi_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Medan/Medan_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Medellin/Medellin_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Medina/Medina_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Meknes/Meknes_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Mendoza/Mendoza_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Merida/Merida_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Misrata/Misrata_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Mit_Ghamr/Mit_Ghamr_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Mogadishu/Mogadishu_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Monteria/Monteria_200m_grid_sara.geoparquet'),
#  (2,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Monterrey/Monterrey_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Montevideo/Montevideo_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Moradabad/Moradabad_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Mosul/Mosul_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Mumbai/Mumbai_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/My_Tho/My_Tho_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Myeik/Myeik_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Nagpur/Nagpur_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Nairobi/Nairobi_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Najaf/Najaf_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Nakuru/Nakuru_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Nalgonda/Nalgonda_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Namangan/Namangan_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Nanchang/Nanchang_200m_grid_sara.geoparquet'),
#  (2,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Nanjing/Nanjing_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Nashik/Nashik_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Nasiriyah/Nasiriyah_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Ndola/Ndola_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Nouakchott/Nouakchott_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Oshogbo/Oshogbo_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Osorno/Osorno_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Ouagadougou/Ouagadougou_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Oujda/Oujda_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Oyo/Oyo_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Padang/Padang_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Palembang/Palembang_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Palmas/Palmas_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Palopo/Palopo_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Panipat/Panipat_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Parbhani/Parbhani_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Pathein/Pathein_200m_grid_sara.geoparquet'),
#  (2,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Patna/Patna_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Pekalongan/Pekalongan_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Pemalang/Pemalang_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Pematang_Siantar/Pematang_Siantar_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Phnom_Penh/Phnom_Penh_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Pingxiang/Pingxiang_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Pingyi/Pingyi_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Pokhara/Pokhara_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Polokwane/Polokwane_200m_grid_sara.geoparquet'),
#  (1,
#   's3://wri-cities-sandbox/identifyingLandSubdivisions/data/output/raster/Pontianak/Pontianak_200m_grid_sara.geoparquet'))

# %%
# Sum the total number of grid cells
total_grid_cells = sum([grid_cells for grid_cells, path in calculated_grids])
print(f'Total grid cells: {total_grid_cells}')
# Out:
# Total grid cells: 462160

# %%
client.close()
